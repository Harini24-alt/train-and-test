# %% [markdown]
# <a href="https://colab.research.google.com/github/Harini24-alt/train-and-test/blob/main/train_and_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Bigmart sales analysis

# %%
import numpy as np
import pandas as pd
#importing the required libraries for the Analysis of the project.

# %% [markdown]
# # Loading of Data

# %%
train = pd.read_csv('/content/Train.csv')
#import necessary libraries and load dataset

# %%
test = pd.read_csv('/content/Test.csv')
#import necessary libraries and load dataset

# %%
train=pd.read_csv('/content/drive/MyDrive/train.csv&test.csv/Train.csv')
# import necessary libraries and load dataset.

# %%
test=pd.read_csv('/content/drive/MyDrive/train.csv&test.csv/Test.csv')
# import necessary libraries and load dataset.

# %%
from google.colab import drive
drive.mount('/content/drive')
#mount google drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Data structure and content

# %%
train.shape
# shape function Helps us identify how many rows and columns we have acoording to our data set
# Out:
# (8523, 12)

# %%
train.columns
#display column names
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
train.isnull().sum()
#display number of missing values of each column
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
train.dtypes
#display the data type of each column
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
train.duplicated()
#check for duplicated rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
train.info()
#display the information about the datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
train.describe()
#display descriptive statistics
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
train.head()
#display first few rows of the datasets
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
train['Item_Type'].value_counts()
#display value counts for 'Item_Type'
# Out:
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64

# %%
train['Item_Fat_Content'].value_counts()
#display value counts for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
test.shape
# shape function Helps us identify how many rows and columns we have acoording to our data set.
# Out:
# (5681, 11)

# %%
test.columns
#display column names
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
train.isnull().sum()
#display number of missing values of each column
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
test.dtypes
#display the data type of each column
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
test.duplicated()
#check for duplicated rows
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5676    False
# 5677    False
# 5678    False
# 5679    False
# 5680    False
# Length: 5681, dtype: bool

# %%
test.info()
#display information about the datasets
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
test.describe()
#display descriptive statistics
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
test.head()
#display first few rows of the datasets
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test['Item_Type'].value_counts()
#display value counts for 'Item_Type'
# Out:
# Item_Type
# Snack Foods              789
# Fruits and Vegetables    781
# Household                638
# Frozen Foods             570
# Dairy                    454
# Baking Goods             438
# Canned                   435
# Health and Hygiene       338
# Meat                     311
# Soft Drinks              281
# Breads                   165
# Hard Drinks              148
# Starchy Foods            121
# Others                   111
# Breakfast                 76
# Seafood                   25
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
#display value counts for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd

#importing the required libraries for the Analysis of the project

# %% [markdown]
# # DATA STRUCTURE AND CONTENT

# %% [markdown]
# # DATA PREPROCESSING

# %%
train['Item_Fat_Content'].value_counts()
#display value counts for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64

# %%
train['Item_Fat_Content'].replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'],inplace=True)
#replace inconsistent values in 'Item_Fat_Content'

# %%
train['Item_Fat_Content'].value_counts()
#display updated value counts for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].value_counts()
#display value counts for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    3396
# Regular    1935
# LF          206
# reg          78
# low fat      66
# Name: count, dtype: int64

# %%
test['Item_Fat_Content'].replace(['LF','low fat','reg'],['Low Fat','Low Fat','Regular'],inplace=True)
#replace inconsistent values in 'Item_Fat_Content'

# %%
test['Item_Fat_Content'].value_counts()
#display updated value counts for 'Item_Fat_Content'
# Out:
# Item_Fat_Content
# Low Fat    3668
# Regular    2013
# Name: count, dtype: int64

# %% [markdown]
# # Explaratory data analysis

# %% [markdown]
# uni variate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import colors
#importing the libraries matplotlib and seaborn

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Item_Fat_Content',data=train)
plt.xlabel('Item_Fat_Content')
plt.show()
# Plot the frequency distribution of 'Item_Fat_Content' with a 3x3 inch figure size

# %% [markdown]
# . The image shows a bar chart comparing the count of items with"Low Fat" and "Regular" fat content.
#
# . The "Low Fat" category has a significantly higher count than the "Regular" category.

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Item_Fat_Content', data=train)
plt.ylabel('Item_Fat_Content')
plt.show()
# Plot the frequency distribution of 'Item_Fat_Content' with a 3x3 inch figure size

# %%
outletsize=train['Outlet_Size'].value_counts(normalize=True)*100
explode=(0.05,0.06,0.07)
colors=('purple','pink','black')
plt.pie(outletsize,labels=outletsize.index,autopct='%1.1f%%',explode=explode,colors=colors)
plt.title('%outletsize')
plt.axis('equal')
plt.show()
 # Create a pie chart showing the percentage distribution colors,explode and title

# %% [markdown]
# . The pie chart depicts the percentage distribution of outlet sizes.
#
# .It reveals that medium-sized outlets hold the majority,according for 45.7%.Small outlets follow with 39.1%,while high outlets represent the smallest share at 15.2%.
#
# .The chart is simply designed, featuring three distinct colors for each category.

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Item_Type', data=train)
plt.ylabel('Item_Type')
plt.show()
# Plot the frequency distribution of 'Item_Type' with a 4x4 inch figure size

# %% [markdown]
# . The image displays a horizontal barchart showing the count of different"Item_Type" categories.
#
# ."Fruits and Vegetables" has the highest count,followed by "Snack Foods","Household", and "Diary".
#
# .Categories like "Seafood" and "Starchy Foods" have the lowest counts.

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Outlet_Location_Type', data=train)
plt.xlabel('Outlet_Location_Type')
plt.show()
# Plot the frequency distribution of 'Outlet_Location_Type'' with a 3x3 inch figure size

# %% [markdown]
# .The image depicts a vertical bar chart illustrating the distribution of outlets across three different location
# types: Tier 1, Tier 2, and Tier 3.
#
# .The chart reveals that Tier 3 has the highest number of outlets, with a count exceeding 3,000.
#
# .Tier 2 follows with a slightly lower count, while Tier 1 has the fewest outlets among the three categories.
#
# .The x-axis represents the different outlet location types, and the y-axis shows the count of outlets.
#
# .This chart helps visualize the concentration of outlets in each tier, highlighting Tier 3 as the most common
# location type.

# %%
plt.figure(figsize=(3,3))
sns.countplot(x='Outlet_Size', data=train)
plt.xlabel('Outlet_Size')
plt.show()
# Plot the frequency distribution of 'Outlet_Size' with a 3x3 inch figure size

# %% [markdown]
# From the graph of outlet size medium outlet size is high,small outlet size is medium and high outlet size is low

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Outlet_Type', data=train)
plt.ylabel('Outlet_Type')
plt.show()
#Plot the frequency distribution of 'Outlet_Type' with a figure size

# %% [markdown]
# Supermarket Type1 is high
# Supermarket Type2 is low
# when compared to others.

# %%
plt.figure(figsize=(3,3))
sns.countplot(y='Outlet_Establishment_Year', data=train)
plt.ylabel('Outlet_Establishment_Year')
plt.show()
#Plot the frequency distribution of 'Outlet_Establishment_Year' with a 5x5 figure size

# %% [markdown]
# . The image shows a horizontal bar chart deplicting the count of outlets established in different years.
#
# .The year 1985 has the highest count,followed by years like 1998,2002 and 2007.

# %% [markdown]
# # To handle the Missing and categorical values

# %%
#To handle the Missing and null values
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for col in train.columns:
  if train[col].dtype=='object':
    train[col]=le.fit_transform(train[col])
# Coverting the labels into a numeric form using Label Encoder for the TRAIN SET.

# %% [markdown]
# purpose:Encodes categorical columns in the DataFrames train as numeric values.

# %%
train['Outlet_Size'].dtypes
#display the data type of 'Outlet_Size' column
# Out:
# dtype('int64')

# %%
train.head()
#display updated few rows of the datsets
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            3
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
# create SimpleImputer object for mean imputation in the TRAIN SET
imputer = SimpleImputer(strategy='mean')

# select columns with missing values
cols_with_missing = ["Item_Weight", 'Outlet_Size']

# impute missing values in selected columns
train[cols_with_missing] = imputer.fit_transform(train[cols_with_missing])

# %%
train.isnull().sum()
#check the number of missing values in each columns after imputation
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
test['Outlet_Size'].dtypes
#display the data type of 'Outlet_Size' column
# Out:
# dtype('O')

# %%
test.head()
#display updated few rows of the datasets
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300          Regular         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test.isnull().sum()
#To check the number of missing values in each column of the test set after imputation.
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %% [markdown]
# # Handling the outliers

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identify outliers')
plt.show()
# Create a horizontal boxplot of numeric columns in the 'train' DataFrame to visually identify potential outliers

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identify outliers')
plt.show()
# Create a horizontal boxplot of numeric columns in the 'test' DataFrame to visually identify potential outliers

# %%
q1=np.percentile(train['Item_Outlet_Sales'],25)
q3=np.percentile(train['Item_Outlet_Sales'],75)
iqr=q3-q1
print('q1',q1)
print('q3',q3)
print('IQR',iqr)
# Calculate and print the first quartile (Q1), third quartile (Q3), and the interquartile range (IQR) of 'Item_Outlet_Sales' in the 'train' DataFrame
# Out:
# q1 834.2474
# q3 3101.2964
# IQR 2267.049

# %%
upperlimit=q3+1.5*iqr
lowerlimit=q1-1.5*iqr
print('upperlimit',upperlimit)
print('lowerlimit',lowerlimit)
# Calculate and print the upper and lower limits for detecting outliers using the 1.5*IQR rule
# Out:
# upperlimit 6501.8699
# lowerlimit -2566.3261

# %% [markdown]
# CUBE TRANSFORMATION

# %%
train['Outlet_sales_cube']=np.cbrt(train['Item_Outlet_Sales'])
# Computes the cube root of the sales data.

# %%
number_columns=train.select_dtypes(include=['int64','float64'])
fig,ax=plt.subplots(figsize=(10,5))
number_columns.boxplot(ax=ax,vert=False,color='blue')
plt.title('identify outliers')
plt.show()
# Selects numerical columns from the DataFrame and plots a horizontal boxplot to help identify outliers.

# %% [markdown]
# The boxplot in the graph identifies outliers primarily in the 'Item_Outlet_Sales' variable,where several values significantly exceed the typical range.Other variables appear to have fewer or no visible outliers

# %% [markdown]
# bi variate analysis

# %%
# Plots a distribution plot of 'Item_Outlet_Sales' with a kernel density estimate (KDE) and rug plot for visualization.
sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# Out:
# <ipython-input-62-084dab4546c5>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Item_Outlet_Sales'],kde=True,rug=True)
# <Axes: xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# The distribution plot shows that "Item_Outlet_Sales" is right-skewed, with a majority of sales concentrated at lower values and a long tail extending toward higher sales. The plot indicates that very high sales are relatively rare.

# %%
# Plots a distribution plot of 'Outlet_Sales_Cube' with a kernel density estimate (KDE) and rug plot for visualization.
sns.distplot(a=train['Outlet_sales_cube'],kde=True,rug=True)
# Out:
# <ipython-input-64-668762f31417>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_sales_cube'],kde=True,rug=True)
# <Axes: xlabel='Outlet_sales_cube', ylabel='Density'>

# %% [markdown]
# The distribution of "Outlet_sales_cube" is approximately normal, with a symmetric bell-shaped curve centered around the mean. This suggests that the data is well-distributed without significant skewness.

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='Item_Outlet_Sales',y='Item_Type',data=train).set(title='Outlet sales vs Item type')
plt.xlabel('Item_Outlet_Sales')
plt.ylabel('Item_Type')
plt.show()
# Set the size of the figure
# Create a bar plot with 'Item_Outlet_Sales' on the x-axis and 'Item_Type' on the y-axis
# Set the labels for the x and y axes
# Display the plot

# %% [markdown]
# Square transformation

# %%
# Computes the square root of the sales data.
train['Outlet_Sales_square']= np.sqrt(train['Item_Outlet_Sales'])

# %%
sns.distplot(a=train['Outlet_Sales_square'],kde=True,rug=True)
#a=train['Outlet_Sales_square']: Specifies the data to be plotted, which in this case is the Outlet_Sales_square column from the train DataFrame.
#kde=True: Adds a Kernel Density Estimate (KDE) line to the plot, which represents the probability density function of the data.
#rug=True: Adds small vertical lines at the bottom of the plot for each data point, giving a sense of the distribution of individual data points.
# Out:
# <ipython-input-67-67c62a71c5f2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=train['Outlet_Sales_square'],kde=True,rug=True)
# <Axes: xlabel='Outlet_Sales_square', ylabel='Density'>

# %% [markdown]
# multivariate analysis

# %%
# Subset the dataset to include only the relevant columns
subset = train[['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type', 'Item_MRP',
             'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
             'Item_Outlet_Sales','Outlet_sales_cube']]

# Calculate the correlation matrix
corr = subset.corr()

# Create a mask for the upper triangle of the heatmap
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the figure and axis objects
fig, ax = plt.subplots(figsize=(10, 8))

# Generate the heatmap with green and white colors
sns.heatmap(corr, mask=mask, annot=True, cmap=sns.diverging_palette(20, 220, n=200),
            center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})

# Set the title and labels for the plot
ax.set_title("Correlation Heatmap", fontsize=18)
ax.set_xlabel("Features", fontsize=14)
ax.set_ylabel("Features", fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# # Future engineering

# %%
train.head()
#Display the first five rows of the 'train' DataFrame
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
# ...

# %%
train['Outlet_Age']=train['Outlet_Establishment_Year'].apply(lambda year:2024-year)
#Calculate the age of each outlet by subtracting the establishment year from 2024
#add it as a new column 'Outlet_Age' to the DataFrame

# %%
train.head()
#Display the first five rows of the train DataFrames
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 0         0.016047          4
# 1                8         5.92                 1         0.019278         14
# 2              662        17.50                 0         0.016760         10
# 3             1121        19.20                 1         0.000000          6
# 4             1297         8.93                 0         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999          1.0
# 1   48.2692                  3                       2009          1.0
# 2  141.6180                  9                       1999          1.0
# 3  182.0950                  0                       1998          3.0
# 4   53.8614                  1                       1987          0.0
#
# ...

# %%
train=train.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Item_Weight','Outlet_Sales_square'],axis=1)
#Remove the specified columns from the train DataFrame
#These columns are dropped as they are not necessary for the analysis or modeling

# %%
train=train.drop(['Item_Visibility','Item_Outlet_Sales'],axis=1)
#Drop the 'Item_Visibility' and 'Item_Outlet_Sales' columns from the train DataFrame
#These columns are removed asa they are not required for the current analysis or modeling

# %%
train.head()
#Display the first five rows of the train DataFrames
# Out:
#    Item_Fat_Content  Item_Type  Item_MRP  Outlet_Location_Type  Outlet_Type  \
# 0                 0          4  249.8092                     0            1
# 1                 1         14   48.2692                     2            2
# 2                 0         10  141.6180                     0            1
# 3                 1          6  182.0950                     2            0
# 4                 0          9   53.8614                     2            1
#
#    Outlet_sales_cube  Outlet_Age
# 0          15.515611          25
# 1           7.625576          15
# 2          12.800240          25
# 3           9.013888          26
# 4           9.982319          37

# %%
from sklearn.preprocessing import StandardScaler
#Import StandardScaler from sklearn.preprocessing for feature standardization

# %%
x=train[['Item_Fat_Content','Item_Type','Item_MRP','Outlet_Location_Type','Outlet_Type','Outlet_Age']]
y=train['Outlet_sales_cube']
#Define the feature varaiables (x) and the target variable (y) for the model

# %%
x.shape
#Display the dimensions of the x DataFrame
# Out:
# (8523, 6)

# %%
scaler=StandardScaler()
#Create an instance of StandardScaler for feature standardization
#This scaler will be used to normalize the features by removing the mean and scaling to unit variance

# %%
x=scaler.fit_transform(x)
#Standardize the feature variables x using the StandardScaler
#This scales the feature to have a mean of 0 and a standard deviation of 1

# %%
x=pd.DataFrame(x)
#Convert the standardized Numpy array x back to a pandas DataFrame
#This allows us to retain DataFrame structures and use column names

# %%
x.head()
#Display the first five rows of the train DataFrame
# Out:
#           0         1         2         3         4         5
# 0 -0.738147 -0.766479  1.747454 -1.369334 -0.252658 -0.139541
# 1  1.354743  1.608963 -1.489023  1.091569  1.002972 -1.334103
# 2 -0.738147  0.658786  0.010040 -1.369334 -0.252658 -0.139541
# 3  1.354743 -0.291391  0.660050  1.091569 -1.508289 -0.020085
# 4 -0.738147  0.421242 -1.399220  1.091569 -0.252658  1.293934

# %%
print(type(x))
#display the type x column
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
test.head()
#Display the first five rows of the test DataFrame
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300          Regular         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
test['Outlet_Age']=test['Outlet_Establishment_Year'].apply(lambda year:2024-year)
# Calculate and add the 'Outlet_Age' column by subtracting 'Outlet_Establishment_Year' from the current year (2024)

# %%
test=test.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Item_Weight',],axis=1)
 #Drop the specified columns from the 'test' DataFrame
# These columns are removed as they are not needed for the analysis or prediction

# %%
test = test.drop(['Item_Visibility'],axis=1)
# Drop the 'Item_Visibility' column from the 'test' DataFrame
# This column is removed as it is not needed for the analysis or prediction

# %%
test.head()
# Display the first five rows of the 'test' DataFrame to inspect its structure and contents
# Out:
#   Item_Fat_Content    Item_Type  Item_MRP Outlet_Location_Type  \
# 0          Low Fat  Snack Foods  107.8622               Tier 1
# 1          Regular        Dairy   87.3198               Tier 2
# 2          Low Fat       Others  241.7538               Tier 3
# 3          Low Fat  Snack Foods  155.0340               Tier 2
# 4          Regular        Dairy  234.2300               Tier 3
#
#          Outlet_Type  Outlet_Age
# 0  Supermarket Type1          25
# 1  Supermarket Type1          17
# 2      Grocery Store          26
# 3  Supermarket Type1          17
# 4  Supermarket Type3          39

# %%
from sklearn.preprocessing import StandardScaler
# Import the StandardScaler class from sklearn.preprocessing for feature standardization
# StandardScaler will be used to normalize features by removing the mean and scaling them to unit variance

# %%
x_test=test[['Item_Fat_Content','Item_Type','Item_MRP','Outlet_Location_Type','Outlet_Type','Outlet_Age']]
# Select specific columns from the 'test' DataFrame to create the feature set 'x_test'
# These columns include 'Item_Fat_Content', 'Item_Type', 'Item_MRP', 'Outlet_Location_Type', 'Outlet_Type', and 'Outlet_Age'

# %%
x_test.shape
# Print the shape of the 'x_test' DataFrame or array to see its dimensions
# Out:
# (5681, 6)

# %%
scaler=StandardScaler()
# Initialize a StandardScaler object for feature standardization

# %%
x_test=pd.DataFrame(x_test)
# Convert the 'x_test' data into a pandas DataFrame
# This allows for easier manipulation and access to DataFrame features

# %%
print(x_test)
# Print the contents of the 'x_test' variable to inspect the test data
# Out:
#      Item_Fat_Content           Item_Type  Item_MRP Outlet_Location_Type  \
# 0             Low Fat         Snack Foods  107.8622               Tier 1
# 1             Regular               Dairy   87.3198               Tier 2
# 2             Low Fat              Others  241.7538               Tier 3
# 3             Low Fat         Snack Foods  155.0340               Tier 2
# 4             Regular               Dairy  234.2300               Tier 3
# ...               ...                 ...       ...                  ...
# 5676          Regular         Snack Foods  141.3154               Tier 1
# 5677          Regular       Starchy Foods  169.1448               Tier 3
# 5678          Low Fat  Health and Hygiene  118.7440               Tier 2
# 5679          Regular              Canned  214.6218               Tier 2
# 5680          Regular              Canned   79.7960               Tier 2
#
#             Outlet_Type  Outlet_Age
# 0     Supermarket Type1          25
# ...

# %%
x_test.head()
#Display the first five rows of the data sets
# Out:
#   Item_Fat_Content    Item_Type  Item_MRP Outlet_Location_Type  \
# 0          Low Fat  Snack Foods  107.8622               Tier 1
# 1          Regular        Dairy   87.3198               Tier 2
# 2          Low Fat       Others  241.7538               Tier 3
# 3          Low Fat  Snack Foods  155.0340               Tier 2
# 4          Regular        Dairy  234.2300               Tier 3
#
#          Outlet_Type  Outlet_Age
# 0  Supermarket Type1          25
# 1  Supermarket Type1          17
# 2      Grocery Store          26
# 3  Supermarket Type1          17
# 4  Supermarket Type3          39

# %%
print(type(x))
# Print the type of the variable 'x' to check its data structure
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# #Model Building

# %%
from sklearn.linear_model import LinearRegression
# Import the LinearRegression class from sklearn.linear_model for creating a linear regression model

# %%
# For evaluating the models using the metrics
from sklearn.metrics import r2_score as R2
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.model_selection  import cross_val_score as CVS

# %%
# Define the linear regression model
lr = LinearRegression()

# Train the model on the training data
lr.fit(x, y)

# Precting the model using the test set
y_predict = lr.predict(x)

# Evaluating the training set with the metric values

print("R-Square value on the training set: = ", lr.score(x,y))
print("----------------------------------------------------------------------------------------------")

# Use cross-validation to get the R-squared score
scores = CVS(lr, x, y, cv=5)
print('CV R-squared scores:', scores,"\n")
print('Average CV R-squared score:',np.mean(scores))
# Out:
# R-Square value on the training set: =  0.5479170954222317
# ----------------------------------------------------------------------------------------------
# CV R-squared scores: [0.55720549 0.56274019 0.52765011 0.53782978 0.54762596]
#
# Average CV R-squared score: 0.5466103056990158

# %% [markdown]
# #Saving The Model

# %%
import pickle
# Import the pickle module for serializing and deserializing Python object

# %%
Bigmart= "BigMart_Analysis.sav"
# Define the filename for saving the model
pickle.dump(lr, open(Bigmart, 'wb'))
# Serialize the trained model 'lr' and save it to the file 'Bigmart_Analysis.sav'

# %% [markdown]
# SUMMARY:
#
# Loading of Data: This step involves bringing the data into a system where it can be analyzed. Think of it as moving the data from spreadsheets into a software tool for analysis.
#
# Data Preprocessing: This is where you clean and prepare the data. It involves fixing any issues with the data to make sure it's ready for analysis.
#
# Exploratory Data Analysis EDA: In this step, you explore the data to find patterns and trends. This helps you understand the data better and spot any interesting insights.
#
# Handling Missing and Categorical Values: Sometimes, data might be missing or in a format that needs special treatment like categories. This step involves filling in missing information and converting categories into a usable format.
#
# Handling Outliers: Outliers are unusual values that can skew results. This step involves identifying and managing these outliers to ensure they dont affect the analysis too much.
#
# Feature Engineering: This is about creating new features or variables from the existing data to improve the analysis. Its like turning raw data into useful information that can help with predictions and decision-making.
#
# In summary, the project involves understanding, cleaning, and preparing the data, exploring it for patterns, handling any issues with missing or unusual values, and creating useful features to make better predictions and decisions.
